# %% [markdown]
# # 1/ Veille

# %% [markdown]
# # 2/ Récupérer les données

# %%
import pandas as pd
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
#table created and filled by command lines
engine = create_engine('mysql+pymysql://myriam:mysql@localhost/regression')
dbConnection=engine.connect()

# %%
donnee_reg = pd.read_sql("select * from donneesreg", dbConnection);
donnee_reg
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15566689  Female   35            57000          0
# 1    15569641  Female   58            95000          1
# 2    15570769  Female   26            80000          0
# 3    15570932    Male   34           115000          0
# 4    15571059  Female   33            41000          0
# ..        ...     ...  ...              ...        ...
# 395  15813113    Male   40           107000          1
# 396  15814004    Male   27            20000          0
# 397  15814553    Male   57            60000          1
# 398  15814816    Male   31            66000          0
# 399  15815236  Female   45           131000          1
#
# [400 rows x 5 columns]

# %%
donnee_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
donnee_reg.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# # 5/a. Visualiser et analyser les données avec les librairies Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D

# %%
# @Anne Laure, celle là est pour toi ;)
#First step of the analysis, is the analysis of the relevance of the data and if necessary data cleaning.
# Checking for the absence of duplicates into User ID (The python data type bool is used to store two values i.e True and False)

x=donnee_reg["User ID"]
import numpy as np
x.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: User ID, dtype: bool

# %%
# Analysis of the correlation between User ID and the Purchased items.
x=donnee_reg["User ID"]
    
y=donnee_reg["Purchased"]

plt.scatter(x,y)
plt.show()

# %%
#De ce que je remarque, le User ID n'a aucune valeur ajoutée pour l'analyse de mes données à ce stade. Je vais me permettre de nettoyer mes données en supprimant la colonne.
donnee_reg.drop(["User ID"],axis='columns',inplace=True)

# %%
donnee_reg.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0  Female   35            57000          0
# 1  Female   58            95000          1
# 2  Female   26            80000          0
# 3    Male   34           115000          0
# 4  Female   33            41000          0

# %%
x=donnee_reg["Gender"]
    
y=donnee_reg["Purchased"]

plt.scatter(x,y)
plt.show()

# %%
#Transform the variable Gendar in numerical number
donnee_reg['GenderNum'] = donnee_reg['Gender'].map({'Male': 1,'Female': 2})
donnee_reg.drop(["Gender"],axis='columns',inplace=True)
donnee_reg.head()
# Out:
#    Age  EstimatedSalary  Purchased  GenderNum
# 0   35            57000          0          2
# 1   58            95000          1          2
# 2   26            80000          0          2
# 3   34           115000          0          1
# 4   33            41000          0          2

# %%
# 3D Projection of the correlation between the gender variable, age and act of purchase
ax=plt.axes(projection='3d')
ax.scatter(donnee_reg.GenderNum,donnee_reg.Age, donnee_reg.EstimatedSalary, c=donnee_reg.Purchased)

# %% [markdown]
# Notre projection 3D, nous montre le genre, l'age, le salaire estimé, et on peut encore en déduire que la répartition entre homme et femme est assez uniforme. La variable genre n'est pas un facteur prédominant dans notre prédiction de Purchase.
# Pour aller encore plus loin dans l'analyse, on va schématiser l'infulence du genre sur l'acte d'achat:

# %%
#gender influence on the act of purchase
table= pd.crosstab(donnee_reg.GenderNum ,donnee_reg.Purchased)
table.div(table.sum(1).astype(float), axis=0).plot (kind='bar', stacked=True)
matplotlib.pyplot.title('Gender / Purchase')
plt.xlabel ('Gender')
plt.ylabel ('percentage of customer')
# Out:
# Text(0, 0.5, 'percentage of customer')

# %%
#with this analysis we can delete the Gender column
donnee_reg.drop(["GenderNum"],axis='columns',inplace=True)
donnee_reg.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   35            57000          0
# 1   58            95000          1
# 2   26            80000          0
# 3   34           115000          0
# 4   33            41000          0

# %%
# Age influence on the act of purchase 
table= pd.crosstab(donnee_reg.Age ,donnee_reg.Purchased)
table.div(table.sum(1).astype(float), axis=0).plot (kind='bar', stacked=True)
matplotlib.pyplot.title('Age / Purchase')
plt.xlabel ('Age')
plt.ylabel ('percentage of customer')
# Out:
# Text(0, 0.5, 'percentage of customer')

# %% [markdown]
# La répartition est moins uniforme que le graphisme en amont. L'age a donc une influence sur l'acte d'achat.

# %%
#### Influence of the EstimatedSalary on the purchase act
table= pd.crosstab(donnee_reg.EstimatedSalary ,donnee_reg.Purchased)
table.div(table.sum(1).astype(float), axis=0).plot (kind='bar', stacked=True)
matplotlib.pyplot.title('EstimatedSalary / Purchase')
plt.xlabel ('Estimated Salary')
plt.ylabel ('percentage of customer')
# Out:
# Text(0, 0.5, 'percentage of customer')

# %% [markdown]
# Pareil, répartition non unifrome, grande disparité en fonction du salaire estimé. Le salaire a donc une influence sur l'acte d'achat.

# %%
#Avec ces informations, nous pouvons créer notre matrice avec la variable dépendante y et les variables indépendantes X
# (l'index commence tjs à 0, donc on prend la 1 ere et la 2 eme colonne de notre outpout 15)
#iloc utilise des entiers pour lire et écrire des données sur un DataFrame
X=donnee_reg.iloc[:,[0,1]].values  # on prend toutes les lignes (:)de la la premiere (index0) et 2 eme colonne (index1)
y=donnee_reg.iloc[:,-1].values      # on prend toutes les lignes de la dernière colonne (-1)

# data visualisation
plt.scatter (X[:,0], X[:,1], c=y)

# %% [markdown]
# L'affichage en nuage de points (plt.scatter), avec L'age pour x; et Estimated salary en y. Avec une coloration des points en fonction de y.
# La représentation nous permet d'appréhender la frontière age/ estimated salary.

# %% [markdown]
# # 5/ b. Visualiser et analyser les données avec les librairies  Seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(donnee_reg.corr(), annot=True, cmap ='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='Purchased', y='EstimatedSalary',   data=donnee_reg,
            jitter=False,
            height=5, aspect=3)

# %%
sns.catplot(x='Purchased', y='EstimatedSalary',   data=donnee_reg,
            jitter=0.25,)

# %%
sns.catplot(x='EstimatedSalary', y='Purchased', 
            data=donnee_reg,
            kind='box',
            height=4, aspect=3.5)

# %%
ax=sns.violinplot(x='Age', y='EstimatedSalary', data=donnee_reg, hue='Purchased', figsize=(20,9))
ax.minorticks_on()
ax.grid(which='minor', axis='x', linewidth=1 )

# %%
from pylab import rcParams
plt.rcParams["figure.figsize"] =[3.2, 2.4]
sns.swarmplot(x='EstimatedSalary', y='Purchased', data=donnee_reg)
plt.show()
# Out:
# /home/myriam/anaconda3/envs/machinelearning/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/myriam/anaconda3/envs/machinelearning/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/myriam/anaconda3/envs/machinelearning/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/myriam/anaconda3/envs/machinelearning/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# # 6/Résoudre le cas d’étude présenté ci-dessous avec la librairie Scikit-Learn.

# %%
import sklearn
from sklearn.model_selection import train_test_split #Split arrays or matrices into random train and test subsets
from sklearn.preprocessing import StandardScaler #Standardize features by removing the mean and scaling to unit variance
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
#Split the dataset between Training set and Test set

# %% [raw]
# #Split the dataset between Training set (jeux d'entrainement, ce qu'on donne à notre model pour qu'il s'entraine, il va analyser les données et essayer de trouver comment il les sépare)
# #and Test set (le jeu de test va nous permettre de vérifier qu'à partir de données que le model ne connait pas; si les prédications sont ou non cohérentes par rapport aux vraies données constatées)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Feature Scaling (mise à l'échelle des matrices)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_test
# Out:
# array([[-1.36213567,  0.4186251 ],
#        [-0.20259715, -0.87761025],
#        [-0.20259715,  0.21240584],
#        [ 0.86031316, -0.78923057],
#        [ 0.2805439 ,  0.21240584],
#        [ 1.05356959,  0.65430425],
#        [-1.07225104, -0.73031078],
#        [ 1.92322348,  0.18294594],
#        [-0.20259715,  0.68376415],
#        [ 0.47380032,  2.39243801],
#        [ 1.05356959,  1.50864118],
#        [-1.07225104, -1.49626803],
#        [-0.20259715, -0.52409152],
#        [ 1.24682601,  0.59538446],
#        [ 0.37717211, -0.67139099],
#        [-0.00934073, -1.02490972],
#        [ 0.86031316,  1.4497214 ],
#        [-1.74864851,  0.06510637],
#        [ 0.18391569, -0.20003268],
#        [-0.49248178,  1.4497214 ],
#        [-0.20259715,  0.21240584],
#        [ 2.1164799 ,  2.21567865],
#        [-1.26550746, -0.37679205],
#        [ 2.21310811,  1.18458235],
#        [ 1.05356959,  0.18294594],
#        [ 1.05356959,  2.06837917],
#        [ 2.21310811, -0.6419311 ],
# ...

# %%
# Model construction
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
classifier.intercept_
# la constante
# Out:
# array([-1.24438212])

# %%
classifier.coef_
# Out:
# array([[2.01453855, 0.90606288]])

# %%
# new predictions vérification de cohérences)
y_pred=classifier.predict(X_test)
classifier.score(X_test, y_test)
# Out:
# 0.88

# %%
# Matrice de confusion (comparaison des résultats)
cm=confusion_matrix(y_test, y_pred)
print (cm)
# Out:
# [[52  3]
#  [ 9 36]]

# %%
 # visulaiser les résultats
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:,0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
            alpha = 0.4, cmap = ListedColormap(('red', 'yellow')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())


plt.contourf(X1,X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape), 
             alpha=0.4, cmap=ListedColormap(('red','green')))
                                   
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
            c = ListedColormap(('red', 'yellow'))(i), label = j)



plt.title('Résultats du Training set')
plt.xlabel ('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
X_predict = sc.transform([[40,100000]])
classifier.predict(X_predict)
# Out:
# array([1])
